# %% [markdown]
# # Small GPT, little update

# %%
#!pip install transformers

# %%
import os
import time
import math
import pickle
from contextlib import nullcontext
import numpy as np
import pandas as pd
import tiktoken
from collections import Counter
import re
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.distributed import init_process_group, destroy_process_group
from torch.utils.data import DataLoader, Dataset
import inspect
from sklearn.model_selection import train_test_split
import random

# %%
# Define the file path
file_path = 'sample_conversations.txt'  # Update this if needed

# Read the file content
with open(file_path, 'r') as file:
    content = file.read()

# Split the content into sentences
sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', content)

# Ensure all sentences are not empty after splitting
sentences = [sentence for sentence in sentences if sentence.strip() != ""]

# Split data into training and validation sets (90% training, 10% validation)
train_sentences, val_sentences = train_test_split(sentences, test_size=0.1, random_state=42)

# Concatenate all training and validation sentences into single texts
train_text = ' '.join(train_sentences)
val_text = ' '.join(val_sentences)

# Encode the data using GPT-2 BPE encoding
enc = tiktoken.get_encoding("gpt2")
train_ids = enc.encode_ordinary(train_text)
val_ids = enc.encode_ordinary(val_text)
print(f"Training data has {len(train_ids):,} tokens")
print(f"Validation data has {len(val_ids):,} tokens")

# Convert to NumPy arrays and save to binary files
train_ids = np.array(train_ids, dtype=np.uint16)
val_ids = np.array(val_ids, dtype=np.uint16)

# Define paths for output files
output_dir = '.'  # You can update this to any directory you want
train_output_path = os.path.join(output_dir, 'train.bin')
val_output_path = os.path.join(output_dir, 'val.bin')

# Save to binary files
train_ids.tofile(train_output_path)
val_ids.tofile(val_output_path)

print(f"Training data saved to {train_output_path}")
print(f"Validation data saved to {val_output_path}")
# Out:
# Training data has 7,088 tokens
# Validation data has 812 tokens
# Training data saved to .\train.bin
# Validation data saved to .\val.bin

# %%
def decode_sample(ids, sample_size):
    sample_ids = ids[:sample_size]
    sample_text = enc.decode(sample_ids.tolist())
    return sample_text

print("Training Data Sample:")
print(decode_sample(train_ids, sample_size=100))

print("\nValidation Data Sample:")
print(decode_sample(val_ids, sample_size=10))
# Out:
# Training Data Sample:
# How was your weekend? How was your weekend? I love reading books. How's the weather today? Yes, I'll be there at 8 PM. Are you coming to the party tonight? It's sunny and warm, perfect for a day outside. Hi there! How are you today? Thanks for asking. I really enjoy Italian cuisine. Hi there! How are you today? Hello! What are your plans for today? Do you have any pets? How's the weather today? Yes,
#
# Validation Data Sample:
# Yes, it was really exciting!
# What's

# %%
# Custom Dataset class
class GPTDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        x = torch.tensor(self.data[idx:idx + self.block_size], dtype=torch.long)
        y = torch.tensor(self.data[idx + 1:idx + 1 + self.block_size], dtype=torch.long)
        return x, y

# Filtering function
def filter_indices(data, max_index):
    return [idx for idx in data if idx < max_index]

class LayerNorm(nn.Module):
    """ LayerNorm but with an optional bias. PyTorch doesn't support simply bias=False """

    def __init__(self, ndim, bias):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(ndim))
        self.bias = nn.Parameter(torch.zeros(ndim)) if bias else None

    def forward(self, input):
        return F.layer_norm(input, self.weight.shape, self.weight, self.bias, 1e-5)

class CausalSelfAttention(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        # regularization
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.dropout = config.dropout
        # flash attention make GPU go brrrrr but support is only in PyTorch >= 2.0
        self.flash = hasattr(torch.nn.functional, 'scaled_dot_product_attention')
        if not self.flash:
            print("WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0")
            # causal mask to ensure that attention is only applied to the left in the input sequence
            self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                        .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k, v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        if self.flash:
            # efficient attention using Flash Attention CUDA kernels
            y = torch.nn.functional.scaled_dot_product_attention(q, k, v, attn_mask=None, dropout_p=self.dropout if self.training else 0, is_causal=True)
        else:
            # manual implementation of attention
            att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
            att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
            att = F.softmax(att, dim=-1)
            att = self.attn_dropout(att)
            y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y

class MLP(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.gelu    = nn.GELU()
        self.c_proj  = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.dropout = nn.Dropout(config.dropout)

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        x = self.dropout(x)
        return x

class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = LayerNorm(config.n_embd, bias=config.bias)
        self.attn = CausalSelfAttention(config)
        self.ln_2 = LayerNorm(config.n_embd, bias=config.bias)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.vocab_size is not None
        assert config.block_size is not None
        self.config = config

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            drop = nn.Dropout(config.dropout),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = LayerNorm(config.n_embd, bias=config.bias),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight  # Weight tying

        # Init all weights
        self.apply(self._init_weights)
        # Apply special scaled init to the residual projections, per GPT-2 paper
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                torch.nn.init.normal_(p, mean=0.0, std=0.02 / math.sqrt(2 * config.n_layer))

        # Report number of parameters
        print("number of parameters: %.2fM" % (self.get_num_params() / 1e6,))

    def get_num_params(self, non_embedding=True):
        n_params = sum(p.numel() for p in self.parameters())
        if non_embedding:
            n_params -= self.transformer.wpe.weight.numel()
        return n_params

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.config.block_size, f"Cannot forward sequence of length {t}, block size is only {self.config.block_size}"
        pos = torch.arange(0, t, dtype=torch.long, device=device)  # shape (t)

        # Forward the GPT model itself
        tok_emb = self.transformer.wte(idx)  # token embeddings of shape (b, t, n_embd)
        pos_emb = self.transformer.wpe(pos)  # position embeddings of shape (t, n_embd)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)

        if targets is not None:
            # If we are given some desired targets also calculate the loss
            logits = self.lm_head(x)
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
        else:
            # Inference-time mini-optimization: only forward the lm_head on the very last position
            logits = self.lm_head(x[:, [-1], :])  # note: using list [-1] to preserve the time dim
            loss = None

        return logits, loss

    def configure_optimizers(self, weight_decay, learning_rate, betas, device_type):
        # start with all of the candidate parameters
        param_dict = {pn: p for pn, p in self.named_parameters()}
        # filter out those that do not require grad
        param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
        # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
        # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
        decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
        nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
        optim_groups = [
            {'params': decay_params, 'weight_decay': weight_decay},
            {'params': nodecay_params, 'weight_decay': 0.0}
        ]
        num_decay_params = sum(p.numel() for p in decay_params)
        num_nodecay_params = sum(p.numel() for p in nodecay_params)
        print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
        print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
        # Create AdamW optimizer and use the fused version if it is available
        fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
        use_fused = fused_available and device_type == 'cuda'
        extra_args = dict(fused=True) if use_fused else dict()
        optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=betas, **extra_args)
        print(f"using fused AdamW: {use_fused}")

        return optimizer

# %%
# Initialize the model
from dataclasses import dataclass

@dataclass
class GPTConfig:
    block_size: int
    vocab_size: int
    n_layer: int
    n_head: int
    n_embd: int  # n_embd must be divisible by n_head
    dropout: float
    bias: bool

config = GPTConfig(
    block_size=8,
    vocab_size= max(max(train_ids), max(val_ids)) + 1,
    n_layer=4,
    n_head=4,
    n_embd=256,  # Ensure n_embd is divisible by n_head
    dropout=0.1,
    bias=True
)

model = GPT(config)
print(model)
# Out:
# number of parameters: 11.63M
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(33073, 256)
#     (wpe): Embedding(8, 256)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-3): 4 x Block(
#         (ln_1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=256, out_features=768, bias=True)
#           (c_proj): Linear(in_features=256, out_features=256, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=256, out_features=1024, bias=True)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1024, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=256, out_features=33073, bias=False)
# )

# %%
# making data and check it
gradient_accumulation_steps = 5 * 8 # used to simulate larger batch sizes
batch_size = 12 # if gradient_accumulation_steps > 1, this is the micro-batch size

# Create Datasets
train_dataset = GPTDataset(train_ids, config.block_size)
val_dataset = GPTDataset(val_ids, config.block_size)

# Print sizes of the datasets
print(f"Size of Training Dataset: {len(train_dataset)}")
print(f"Size of Validation Dataset: {len(val_dataset)}")

# Function to print a few samples as numbers
def print_samples_as_numbers(dataset, num_samples=5):
    for i in range(num_samples):
        x, y = dataset[i]
        print(f"Sample {i + 1} as numbers")
        print(f"x: {x.numpy()}")
        print(f"y: {y.numpy()}")
        print("-" * 50)

# Function to print a few samples as decoded text
def print_samples_as_text(dataset, enc, sample_size=100, num_samples=5):
    for i in range(num_samples):
        x, y = dataset[i]
        x_text = decode_sample(x, sample_size)
        y_text = decode_sample(y, sample_size)
        print(f"Sample {i + 1} as text")
        print(f"x: {x_text}")
        print(f"y: {y_text}")
        print("-" * 50)

# Print first 5 samples from the train dataset as numbers
print("Train Dataset Samples as Numbers:")
print_samples_as_numbers(train_dataset)

# Print first 5 samples from the train dataset as text
print("\nTrain Dataset Samples as Text:")
print_samples_as_text(train_dataset, enc, sample_size=100)

# Create DataLoaders
gradient_accumulation_steps = 5 * 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Print size of DataLoader
num_train_batches = len(train_loader)
num_val_batches = len(val_loader)
print(f"Number of batches in Training DataLoader: {num_train_batches}")
print(f"Number of batches in Validation DataLoader: {num_val_batches}")


# Initialize optimizer
device = 'cuda' if torch.cuda.is_available() else 'cpu'
optimizer = model.configure_optimizers(weight_decay=0.1, learning_rate=3e-4, betas=(0.9, 0.95), device_type=device)
# Out:
# Size of Training Dataset: 7080
# Size of Validation Dataset: 804
# Train Dataset Samples as Numbers:
# Sample 1 as numbers
# x: [2437  373  534 5041   30 1374  373  534]
# y: [ 373  534 5041   30 1374  373  534 5041]
# --------------------------------------------------
# Sample 2 as numbers
# x: [ 373  534 5041   30 1374  373  534 5041]
# y: [ 534 5041   30 1374  373  534 5041   30]
# --------------------------------------------------
# Sample 3 as numbers
# x: [ 534 5041   30 1374  373  534 5041   30]
# y: [5041   30 1374  373  534 5041   30  314]
# --------------------------------------------------
# Sample 4 as numbers
# x: [5041   30 1374  373  534 5041   30  314]
# y: [  30 1374  373  534 5041   30  314 1842]
# --------------------------------------------------
# Sample 5 as numbers
# x: [  30 1374  373  534 5041   30  314 1842]
# y: [1374  373  534 5041   30  314 1842 3555]
# --------------------------------------------------
#
# Train Dataset Samples as Text:
# Sample 1 as text
# x: How was your weekend? How was your
# y:  was your weekend? How was your weekend
# --------------------------------------------------
# Sample 2 as text
# x:  was your weekend? How was your weekend
# y:  your weekend? How was your weekend?
# --------------------------------------------------
# Sample 3 as text
# x:  your weekend? How was your weekend?
# y:  weekend? How was your weekend? I
# --------------------------------------------------
# Sample 4 as text
# x:  weekend? How was your weekend? I
# y: ? How was your weekend? I love
# --------------------------------------------------
# Sample 5 as text
# x: ? How was your weekend? I love
# y:  How was your weekend? I love reading
# --------------------------------------------------
# Number of batches in Training DataLoader: 590
# Number of batches in Validation DataLoader: 67
# num decayed parameter tensors: 18, with 11,614,464 parameters
# num non-decayed parameter tensors: 34, with 13,824 parameters
# using fused AdamW: False

# %%
# Define the learning rate scheduler

# Global variables for learning rate scheduling
decay_lr = True  # whether to decay the learning rate
warmup_iters = 2000  # how many steps to warm up for
lr_decay_iters = 600000  # should be ~= max_iters per Chinchilla
min_lr = 6e-5  # minimum learning rate, should be ~= learning_rate/10 per Chinchilla
learning_rate = 3e-4  # initial learning rate

def get_lr(it):
    # 1) Linear warmup for warmup_iters steps
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    # 2) If it > lr_decay_iters, return min learning rate
    if it > lr_decay_iters:
        return min_lr
    # 3) In between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))  # coeff ranges 0..1
    return min_lr + coeff * (learning_rate - min_lr)

def print_sample_as_text(x, y, enc, train_val):
    random_idx = random.randint(0, x.size(0) - 1)  # Get a random index from the batch
    x_text = decode_data(x[random_idx], enc)
    y_text = decode_data(y[random_idx], enc)
    print("Random Sample as text from  ", train_val)
    print(f"x: {x_text}")
    print(f"y: {y_text}")
    print("-" * 50)

def decode_data(ids, enc):
    sample_ids = ids.tolist()  # Convert tensor to list of integers
    sample_text = enc.decode(sample_ids)
    return sample_text

# %%
def train(model, train_loader, val_loader, optimizer, config, epochs=1, gradient_accumulation_steps=1):
    device = torch.device('cpu')
    model.to(device)
    model.train()
    iter_num = 0
    best_val_loss = float('inf')

    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (x, y) in enumerate(train_loader):
            x, y = x.to(device), y.to(device)

            # Update learning rate
            lr = get_lr(iter_num)
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
                
            logits, loss = model(x, y)
            loss = loss / gradient_accumulation_steps
            loss.backward()

            if (batch_idx + 1) % gradient_accumulation_steps == 0:
                optimizer.step()
                optimizer.zero_grad()
                iter_num += 1

                # Logging
                running_loss += loss.item()
                if iter_num % 5 == 0:
                    avg_loss = running_loss / 5
                    print(f'Epoch {epoch+1}/{epochs}, Iteration {iter_num}, Avg Loss: {avg_loss:.4f}')

                    # Print a random training sample as text
                    print_sample_as_text(x, y, enc,"Training")  # Print a random sample in the batch

                    running_loss = 0.0

        # Validation
        val_loss = evaluate(model, val_loader, device)
        print(f'Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss:.4f}')

        # Save the best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'best_model.pt')
            print(f'Saving model with validation loss: {val_loss:.4f}')

def evaluate(model, val_loader, device):
    model.eval()
    val_loss = 0
    random_sample_printed = False  # Flag to ensure only one sample is printed
    with torch.no_grad():
        for x, y in val_loader:
            x, y = x.to(device), y.to(device)
            logits, loss = model(x, y)
            val_loss += loss.item()
            # Print one random sample from the validation set
            if not random_sample_printed:
                print_sample_as_text(x, y, enc,"Validation")
                random_sample_printed = True
    val_loss /= len(val_loader)
    model.train()
    return val_loss

# Train the model
train(model, train_loader, val_loader, optimizer, config, epochs=100, gradient_accumulation_steps=gradient_accumulation_steps)
# Out:
# Epoch 1/100, Iteration 5, Avg Loss: 0.2619
# Random Sample as text from   Training
# x:  Hello! What are your plans for today
# y: ! What are your plans for today?
# --------------------------------------------------
# Epoch 1/100, Iteration 10, Avg Loss: 0.2613
# Random Sample as text from   Training
# x:  in the park. I really enjoy Italian
# y:  the park. I really enjoy Italian cuisine
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 1/100, Validation Loss: 10.3935
# Saving model with validation loss: 10.3935
# Epoch 2/100, Iteration 15, Avg Loss: 0.0523
# Random Sample as text from   Training
# x:  I went hiking. How's the weather
# y:  went hiking. How's the weather today
# --------------------------------------------------
# Epoch 2/100, Iteration 20, Avg Loss: 0.2592
# Random Sample as text from   Training
# x: 's your favorite food? Do you have
# y:  your favorite food? Do you have any
# --------------------------------------------------
# Epoch 2/100, Iteration 25, Avg Loss: 0.2581
# Random Sample as text from   Training
# x: ! Did you sleep well? I love
# y:  Did you sleep well? I love reading
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 2/100, Validation Loss: 10.1410
# Saving model with validation loss: 10.1410
# Epoch 3/100, Iteration 30, Avg Loss: 0.1017
# Random Sample as text from   Training
# x: 's your favorite food? Do you have
# y:  your favorite food? Do you have any
# --------------------------------------------------
# Epoch 3/100, Iteration 35, Avg Loss: 0.2524
# Random Sample as text from   Training
# x: ! What are your plans for today?
# y:  What are your plans for today? Do
# --------------------------------------------------
# Epoch 3/100, Iteration 40, Avg Loss: 0.2500
# Random Sample as text from   Training
# x: 'm doing well, thank you!
#
# y:  doing well, thank you!
# Good
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 3/100, Validation Loss: 9.8531
# Saving model with validation loss: 9.8531
# Epoch 4/100, Iteration 45, Avg Loss: 0.1485
# Random Sample as text from   Training
# x:  I went hiking. It was great,
# y:  went hiking. It was great, I
# --------------------------------------------------
# Epoch 4/100, Iteration 50, Avg Loss: 0.2465
# Random Sample as text from   Training
# x:  you!
# Good morning! Did you
# y: !
# Good morning! Did you sleep
# --------------------------------------------------
# Epoch 4/100, Iteration 55, Avg Loss: 0.2432
# Random Sample as text from   Training
# x:  you have any pets? I'm planning
# y:  have any pets? I'm planning to
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 4/100, Validation Loss: 9.6174
# Saving model with validation loss: 9.6174
# Epoch 5/100, Iteration 60, Avg Loss: 0.1935
# Random Sample as text from   Training
# x:  game last night? It's sunny and
# y:  last night? It's sunny and warm
# --------------------------------------------------
# Epoch 5/100, Iteration 65, Avg Loss: 0.2394
# Random Sample as text from   Training
# x:  sunny and warm, perfect for a day
# y:  and warm, perfect for a day outside
# --------------------------------------------------
# Epoch 5/100, Iteration 70, Avg Loss: 0.2374
# Random Sample as text from   Training
# x:  food? Yes, I have a dog
# y: ? Yes, I have a dog named
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 5/100, Validation Loss: 9.3768
# Saving model with validation loss: 9.3768
# Epoch 6/100, Iteration 75, Avg Loss: 0.2361
# Random Sample as text from   Training
# x:  did. I love reading books. What
# y: . I love reading books. What's
# --------------------------------------------------
# Epoch 6/100, Iteration 80, Avg Loss: 0.2333
# Random Sample as text from   Training
# x:  in the park. What's your favorite
# y:  the park. What's your favorite food
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 6/100, Validation Loss: 9.0107
# Saving model with validation loss: 9.0107
# Epoch 7/100, Iteration 85, Avg Loss: 0.0460
# Random Sample as text from   Training
# x:  game last night? I love reading books
# y:  last night? I love reading books.
# --------------------------------------------------
# Epoch 7/100, Iteration 90, Avg Loss: 0.2273
# Random Sample as text from   Training
# x: 's your favorite hobby? Hi there!
# y:  your favorite hobby? Hi there! How
# --------------------------------------------------
# Epoch 7/100, Iteration 95, Avg Loss: 0.2242
# Random Sample as text from   Training
# x:  today? Are you coming to the party
# y: ? Are you coming to the party tonight
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 7/100, Validation Loss: 8.5838
# Saving model with validation loss: 8.5838
# Epoch 8/100, Iteration 100, Avg Loss: 0.0886
# Random Sample as text from   Training
# x: ? Hi there! How are you today
# y:  Hi there! How are you today?
# --------------------------------------------------
# Epoch 8/100, Iteration 105, Avg Loss: 0.2173
# Random Sample as text from   Training
# x:  your weekend? Yes, I'll be
# y:  weekend? Yes, I'll be there
# --------------------------------------------------
# Epoch 8/100, Iteration 110, Avg Loss: 0.2138
# Random Sample as text from   Training
# x:  you coming to the party tonight? Do
# y:  coming to the party tonight? Do you
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 8/100, Validation Loss: 8.1051
# Saving model with validation loss: 8.1051
# Epoch 9/100, Iteration 115, Avg Loss: 0.1243
# Random Sample as text from   Training
# x:  was your weekend? I'm doing well
# y:  your weekend? I'm doing well,
# --------------------------------------------------
# Epoch 9/100, Iteration 120, Avg Loss: 0.2048
# Random Sample as text from   Training
# x: . I love reading books. Are you
# y:  I love reading books. Are you coming
# --------------------------------------------------
# Epoch 9/100, Iteration 125, Avg Loss: 0.2020
# Random Sample as text from   Training
# x:  sunny and warm, perfect for a day
# y:  and warm, perfect for a day outside
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 9/100, Validation Loss: 7.6560
# Saving model with validation loss: 7.6560
# Epoch 10/100, Iteration 130, Avg Loss: 0.1593
# Random Sample as text from   Training
# x:  the party tonight? Are you coming to
# y:  party tonight? Are you coming to the
# --------------------------------------------------
# Epoch 10/100, Iteration 135, Avg Loss: 0.1967
# Random Sample as text from   Training
# x:  planning to go for a walk in the
# y:  to go for a walk in the park
# --------------------------------------------------
# Epoch 10/100, Iteration 140, Avg Loss: 0.1912
# Random Sample as text from   Training
# x: ? It was great, I went hiking
# y:  It was great, I went hiking.
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 10/100, Validation Loss: 7.2749
# Saving model with validation loss: 7.2749
# Epoch 11/100, Iteration 145, Avg Loss: 0.1881
# Random Sample as text from   Training
# x: ? Hello! What are your plans for
# y:  Hello! What are your plans for today
# --------------------------------------------------
# Epoch 11/100, Iteration 150, Avg Loss: 0.1855
# Random Sample as text from   Training
# x: , I have a dog named Max.
# y:  I have a dog named Max. How
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  was really exciting!
# What's your
# y:  really exciting!
# What's your favorite
# --------------------------------------------------
# Epoch 11/100, Validation Loss: 6.9562
# Saving model with validation loss: 6.9562
# Epoch 12/100, Iteration 155, Avg Loss: 0.0367
# Random Sample as text from   Training
# x:  I really enjoy Italian cuisine. Are you
# y:  really enjoy Italian cuisine. Are you coming
# --------------------------------------------------
# Epoch 12/100, Iteration 160, Avg Loss: 0.1813
# Random Sample as text from   Training
# x:  any pets? Yes, I have a
# y:  pets? Yes, I have a dog
# --------------------------------------------------
# Epoch 12/100, Iteration 165, Avg Loss: 0.1793
# Random Sample as text from   Training
# x:  are your plans for today? Do you
# y:  your plans for today? Do you have
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 12/100, Validation Loss: 6.6843
# Saving model with validation loss: 6.6843
# Epoch 13/100, Iteration 170, Avg Loss: 0.0695
# Random Sample as text from   Training
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 13/100, Iteration 175, Avg Loss: 0.1754
# Random Sample as text from   Training
# x:  I went hiking. Hello! What are
# y:  went hiking. Hello! What are your
# --------------------------------------------------
# Epoch 13/100, Iteration 180, Avg Loss: 0.1717
# Random Sample as text from   Training
# x:  How are you today? I'm doing
# y:  are you today? I'm doing well
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 13/100, Validation Loss: 6.4499
# Saving model with validation loss: 6.4499
# Epoch 14/100, Iteration 185, Avg Loss: 0.1018
# Random Sample as text from   Training
# x:  morning! Did you sleep well? Yes
# y: ! Did you sleep well? Yes,
# --------------------------------------------------
# Epoch 14/100, Iteration 190, Avg Loss: 0.1682
# Random Sample as text from   Training
# x: . I love reading books. Are you
# y:  I love reading books. Are you coming
# --------------------------------------------------
# Epoch 14/100, Iteration 195, Avg Loss: 0.1670
# Random Sample as text from   Training
# x:  doing well, thank you!
# Good
# y:  well, thank you!
# Good morning
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 14/100, Validation Loss: 6.2358
# Saving model with validation loss: 6.2358
# Epoch 15/100, Iteration 200, Avg Loss: 0.1298
# Random Sample as text from   Training
# x: ? Yes, it was really exciting!
# y:  Yes, it was really exciting!
#
# --------------------------------------------------
# Epoch 15/100, Iteration 205, Avg Loss: 0.1614
# Random Sample as text from   Training
# x:  What are your plans for today? Hello
# y:  are your plans for today? Hello!
# --------------------------------------------------
# Epoch 15/100, Iteration 210, Avg Loss: 0.1600
# Random Sample as text from   Training
# x:  reading books. Yes, I'll be
# y:  books. Yes, I'll be there
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  favorite hobby? What's your favorite food
# y:  hobby? What's your favorite food?
# --------------------------------------------------
# Epoch 15/100, Validation Loss: 6.0249
# Saving model with validation loss: 6.0249
# Epoch 16/100, Iteration 215, Avg Loss: 0.1573
# Random Sample as text from   Training
# x: ? How was your weekend? I love
# y:  How was your weekend? I love reading
# --------------------------------------------------
# Epoch 16/100, Iteration 220, Avg Loss: 0.1553
# Random Sample as text from   Training
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 16/100, Validation Loss: 5.8113
# Saving model with validation loss: 5.8113
# Epoch 17/100, Iteration 225, Avg Loss: 0.0304
# Random Sample as text from   Training
# x: 'm doing well, thank you!
#
# y:  doing well, thank you!
# Good
# --------------------------------------------------
# Epoch 17/100, Iteration 230, Avg Loss: 0.1520
# Random Sample as text from   Training
# x:  8 PM. Hello! What are your
# y:  PM. Hello! What are your plans
# --------------------------------------------------
# Epoch 17/100, Iteration 235, Avg Loss: 0.1496
# Random Sample as text from   Training
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 17/100, Validation Loss: 5.5885
# Saving model with validation loss: 5.5885
# Epoch 18/100, Iteration 240, Avg Loss: 0.0587
# Random Sample as text from   Training
# x: 's sunny and warm, perfect for a
# y:  sunny and warm, perfect for a day
# --------------------------------------------------
# Epoch 18/100, Iteration 245, Avg Loss: 0.1451
# Random Sample as text from   Training
# x:  party tonight? I love reading books.
# y:  tonight? I love reading books. Did
# --------------------------------------------------
# Epoch 18/100, Iteration 250, Avg Loss: 0.1424
# Random Sample as text from   Training
# x:  coming to the party tonight? Are you
# y:  to the party tonight? Are you coming
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 18/100, Validation Loss: 5.3514
# Saving model with validation loss: 5.3514
# Epoch 19/100, Iteration 255, Avg Loss: 0.0851
# Random Sample as text from   Training
# x: , I went hiking. Are you coming
# y:  I went hiking. Are you coming to
# --------------------------------------------------
# Epoch 19/100, Iteration 260, Avg Loss: 0.1393
# Random Sample as text from   Training
# x:  Yes, I'll be there at 8
# y: , I'll be there at 8 PM
# --------------------------------------------------
# Epoch 19/100, Iteration 265, Avg Loss: 0.1363
# Random Sample as text from   Training
# x:  great, I went hiking. Thanks for
# y: , I went hiking. Thanks for asking
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 19/100, Validation Loss: 5.1084
# Saving model with validation loss: 5.1084
# Epoch 20/100, Iteration 270, Avg Loss: 0.1071
# Random Sample as text from   Training
# x:  day outside. How's the weather today
# y:  outside. How's the weather today?
# --------------------------------------------------
# Epoch 20/100, Iteration 275, Avg Loss: 0.1337
# Random Sample as text from   Training
# x: ? How was your weekend? Are you
# y:  How was your weekend? Are you coming
# --------------------------------------------------
# Epoch 20/100, Iteration 280, Avg Loss: 0.1312
# Random Sample as text from   Training
# x:  your favorite food? Are you coming to
# y:  favorite food? Are you coming to the
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Epoch 20/100, Validation Loss: 4.8619
# Saving model with validation loss: 4.8619
# Epoch 21/100, Iteration 285, Avg Loss: 0.1287
# Random Sample as text from   Training
# x:  have any pets? Yes, it was
# y:  any pets? Yes, it was really
# --------------------------------------------------
# Epoch 21/100, Iteration 290, Avg Loss: 0.1247
# Random Sample as text from   Training
# x: ? Yes, I did. I really
# y:  Yes, I did. I really enjoy
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  favorite hobby? What's your favorite food
# y:  hobby? What's your favorite food?
# --------------------------------------------------
# Epoch 21/100, Validation Loss: 4.6207
# Saving model with validation loss: 4.6207
# Epoch 22/100, Iteration 295, Avg Loss: 0.0246
# Random Sample as text from   Training
# x:  Hello! What are your plans for today
# y: ! What are your plans for today?
# --------------------------------------------------
# Epoch 22/100, Iteration 300, Avg Loss: 0.1206
# Random Sample as text from   Training
# x:  for asking. Do you have any pets
# y:  asking. Do you have any pets?
# --------------------------------------------------
# Epoch 22/100, Iteration 305, Avg Loss: 0.1184
# Random Sample as text from   Training
# x: ! Did you sleep well? Hi there
# y:  Did you sleep well? Hi there!
# --------------------------------------------------
# Random Sample as text from   Validation
# x: !
# What's your favorite hobby?
# y:
# What's your favorite hobby? What
# --------------------------------------------------
# Epoch 22/100, Validation Loss: 4.3794
# Saving model with validation loss: 4.3794
# Epoch 23/100, Iteration 310, Avg Loss: 0.0466
# Random Sample as text from   Training
# x: ? How was your weekend? Yes,
# y:  How was your weekend? Yes, I
# --------------------------------------------------
# Epoch 23/100, Iteration 315, Avg Loss: 0.1141
# Random Sample as text from   Training
# x:  sleep well? I really enjoy Italian cuisine
# y:  well? I really enjoy Italian cuisine.
# --------------------------------------------------
# Epoch 23/100, Iteration 320, Avg Loss: 0.1118
# Random Sample as text from   Training
# x:  night? I really enjoy Italian cuisine.
# y: ? I really enjoy Italian cuisine. Did
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 23/100, Validation Loss: 4.1336
# Saving model with validation loss: 4.1336
# Epoch 24/100, Iteration 325, Avg Loss: 0.0654
# Random Sample as text from   Training
# x: , I have a dog named Max.
# y:  I have a dog named Max. Yes
# --------------------------------------------------
# Epoch 24/100, Iteration 330, Avg Loss: 0.1063
# Random Sample as text from   Training
# x:  sleep well? How was your weekend?
# y:  well? How was your weekend? Yes
# --------------------------------------------------
# Epoch 24/100, Iteration 335, Avg Loss: 0.1029
# Random Sample as text from   Training
# x: . Hi there! How are you today
# y:  Hi there! How are you today?
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 24/100, Validation Loss: 3.8838
# Saving model with validation loss: 3.8838
# Epoch 25/100, Iteration 340, Avg Loss: 0.0819
# Random Sample as text from   Training
# x:  watch the game last night? Did you
# y:  the game last night? Did you watch
# --------------------------------------------------
# Epoch 25/100, Iteration 345, Avg Loss: 0.1002
# Random Sample as text from   Training
# x: ? How's the weather today? Yes
# y:  How's the weather today? Yes,
# --------------------------------------------------
# Epoch 25/100, Iteration 350, Avg Loss: 0.0963
# Random Sample as text from   Training
# x:  food? How was your weekend? Hello
# y: ? How was your weekend? Hello!
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  was really exciting!
# What's your
# y:  really exciting!
# What's your favorite
# --------------------------------------------------
# Epoch 25/100, Validation Loss: 3.6241
# Saving model with validation loss: 3.6241
# Epoch 26/100, Iteration 355, Avg Loss: 0.0937
# Random Sample as text from   Training
# x:  Hi there! How are you today?
# y:  there! How are you today? How
# --------------------------------------------------
# Epoch 26/100, Iteration 360, Avg Loss: 0.0926
# Random Sample as text from   Training
# x:  for today? I'm doing well,
# y:  today? I'm doing well, thank
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 26/100, Validation Loss: 3.3593
# Saving model with validation loss: 3.3593
# Epoch 27/100, Iteration 365, Avg Loss: 0.0178
# Random Sample as text from   Training
# x:  to the party tonight? I really enjoy
# y:  the party tonight? I really enjoy Italian
# --------------------------------------------------
# Epoch 27/100, Iteration 370, Avg Loss: 0.0874
# Random Sample as text from   Training
# x:  for today? I'm planning to go
# y:  today? I'm planning to go for
# --------------------------------------------------
# Epoch 27/100, Iteration 375, Avg Loss: 0.0850
# Random Sample as text from   Training
# x:  to the party tonight? Yes, I
# y:  the party tonight? Yes, I did
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 27/100, Validation Loss: 3.0863
# Saving model with validation loss: 3.0863
# Epoch 28/100, Iteration 380, Avg Loss: 0.0322
# Random Sample as text from   Training
# x:  How's the weather today? Did you
# y: 's the weather today? Did you watch
# --------------------------------------------------
# Epoch 28/100, Iteration 385, Avg Loss: 0.0807
# Random Sample as text from   Training
# x: Good morning! Did you sleep well?
# y:  morning! Did you sleep well? I
# --------------------------------------------------
# Epoch 28/100, Iteration 390, Avg Loss: 0.0769
# Random Sample as text from   Training
# x:  to go for a walk in the park
# y:  go for a walk in the park.
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# What's your favorite hobby? What
# y: What's your favorite hobby? What's
# --------------------------------------------------
# Epoch 28/100, Validation Loss: 2.8103
# Saving model with validation loss: 2.8103
# Epoch 29/100, Iteration 395, Avg Loss: 0.0443
# Random Sample as text from   Training
# x:  go for a walk in the park.
# y:  for a walk in the park. What
# --------------------------------------------------
# Epoch 29/100, Iteration 400, Avg Loss: 0.0712
# Random Sample as text from   Training
# x:  for asking. What's your favorite food
# y:  asking. What's your favorite food?
# --------------------------------------------------
# Epoch 29/100, Iteration 405, Avg Loss: 0.0689
# Random Sample as text from   Training
# x:  Yes, I'll be there at 8
# y: , I'll be there at 8 PM
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 29/100, Validation Loss: 2.5358
# Saving model with validation loss: 2.5358
# Epoch 30/100, Iteration 410, Avg Loss: 0.0524
# Random Sample as text from   Training
# x:  warm, perfect for a day outside.
# y: , perfect for a day outside. How
# --------------------------------------------------
# Epoch 30/100, Iteration 415, Avg Loss: 0.0654
# Random Sample as text from   Training
# x: 's your favorite hobby? Yes, I
# y:  your favorite hobby? Yes, I'll
# --------------------------------------------------
# Epoch 30/100, Iteration 420, Avg Loss: 0.0614
# Random Sample as text from   Training
# x:  outside. Do you have any pets?
# y: . Do you have any pets? I
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 30/100, Validation Loss: 2.2626
# Saving model with validation loss: 2.2626
# Epoch 31/100, Iteration 425, Avg Loss: 0.0590
# Random Sample as text from   Training
# x:  sunny and warm, perfect for a day
# y:  and warm, perfect for a day outside
# --------------------------------------------------
# Epoch 31/100, Iteration 430, Avg Loss: 0.0565
# Random Sample as text from   Training
# x: ! Did you sleep well? I really
# y:  Did you sleep well? I really enjoy
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 31/100, Validation Loss: 2.0004
# Saving model with validation loss: 2.0004
# Epoch 32/100, Iteration 435, Avg Loss: 0.0107
# Random Sample as text from   Training
# x:  reading books. Yes, I'll be
# y:  books. Yes, I'll be there
# --------------------------------------------------
# Epoch 32/100, Iteration 440, Avg Loss: 0.0513
# Random Sample as text from   Training
# x:  sunny and warm, perfect for a day
# y:  and warm, perfect for a day outside
# --------------------------------------------------
# Epoch 32/100, Iteration 445, Avg Loss: 0.0508
# Random Sample as text from   Training
# x: . Yes, I'll be there at
# y:  Yes, I'll be there at 8
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 32/100, Validation Loss: 1.7522
# Saving model with validation loss: 1.7522
# Epoch 33/100, Iteration 450, Avg Loss: 0.0192
# Random Sample as text from   Training
# x:  Yes, I did. Did you watch
# y: , I did. Did you watch the
# --------------------------------------------------
# Epoch 33/100, Iteration 455, Avg Loss: 0.0456
# Random Sample as text from   Training
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 33/100, Iteration 460, Avg Loss: 0.0420
# Random Sample as text from   Training
# x:  pets? It was great, I went
# y: ? It was great, I went hiking
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 33/100, Validation Loss: 1.5267
# Saving model with validation loss: 1.5267
# Epoch 34/100, Iteration 465, Avg Loss: 0.0243
# Random Sample as text from   Training
# x: !
# What's your favorite hobby?
# y:
# What's your favorite hobby? Do
# --------------------------------------------------
# Epoch 34/100, Iteration 470, Avg Loss: 0.0398
# Random Sample as text from   Training
# x:  really enjoy Italian cuisine. Did you watch
# y:  enjoy Italian cuisine. Did you watch the
# --------------------------------------------------
# Epoch 34/100, Iteration 475, Avg Loss: 0.0367
# Random Sample as text from   Training
# x: ? I love reading books. I love
# y:  I love reading books. I love reading
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 34/100, Validation Loss: 1.3196
# Saving model with validation loss: 1.3196
# Epoch 35/100, Iteration 480, Avg Loss: 0.0273
# Random Sample as text from   Training
# x: Good morning! Did you sleep well?
# y:  morning! Did you sleep well? How
# --------------------------------------------------
# Epoch 35/100, Iteration 485, Avg Loss: 0.0336
# Random Sample as text from   Training
# x:  there! How are you today? I
# y: ! How are you today? I'm
# --------------------------------------------------
# Epoch 35/100, Iteration 490, Avg Loss: 0.0318
# Random Sample as text from   Training
# x:  outside. I really enjoy Italian cuisine.
# y: . I really enjoy Italian cuisine. Yes
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 35/100, Validation Loss: 1.1454
# Saving model with validation loss: 1.1454
# Epoch 36/100, Iteration 495, Avg Loss: 0.0316
# Random Sample as text from   Training
# x:  great, I went hiking. Thanks for
# y: , I went hiking. Thanks for asking
# --------------------------------------------------
# Epoch 36/100, Iteration 500, Avg Loss: 0.0294
# Random Sample as text from   Training
# x:  I went hiking. I love reading books
# y:  went hiking. I love reading books.
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 36/100, Validation Loss: 0.9966
# Saving model with validation loss: 0.9966
# Epoch 37/100, Iteration 505, Avg Loss: 0.0053
# Random Sample as text from   Training
# x: ? Thanks for asking. What's your
# y:  Thanks for asking. What's your favorite
# --------------------------------------------------
# Epoch 37/100, Iteration 510, Avg Loss: 0.0269
# Random Sample as text from   Training
# x:  have a dog named Max. How's
# y:  a dog named Max. How's the
# --------------------------------------------------
# Epoch 37/100, Iteration 515, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: , I went hiking. What's your
# y:  I went hiking. What's your favorite
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 37/100, Validation Loss: 0.8742
# Saving model with validation loss: 0.8742
# Epoch 38/100, Iteration 520, Avg Loss: 0.0092
# Random Sample as text from   Training
# x: ? How was your weekend? It was
# y:  How was your weekend? It was great
# --------------------------------------------------
# Epoch 38/100, Iteration 525, Avg Loss: 0.0218
# Random Sample as text from   Training
# x:  How are you today? I'm doing
# y:  are you today? I'm doing well
# --------------------------------------------------
# Epoch 38/100, Iteration 530, Avg Loss: 0.0211
# Random Sample as text from   Training
# x:  are your plans for today? How's
# y:  your plans for today? How's the
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 38/100, Validation Loss: 0.7820
# Saving model with validation loss: 0.7820
# Epoch 39/100, Iteration 535, Avg Loss: 0.0115
# Random Sample as text from   Training
# x:  night? It's sunny and warm,
# y: ? It's sunny and warm, perfect
# --------------------------------------------------
# Epoch 39/100, Iteration 540, Avg Loss: 0.0196
# Random Sample as text from   Training
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 39/100, Iteration 545, Avg Loss: 0.0187
# Random Sample as text from   Training
# x: 's the weather today? Yes, it
# y:  the weather today? Yes, it was
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Epoch 39/100, Validation Loss: 0.7035
# Saving model with validation loss: 0.7035
# Epoch 40/100, Iteration 550, Avg Loss: 0.0140
# Random Sample as text from   Training
# x:  Are you coming to the party tonight?
# y:  you coming to the party tonight? Yes
# --------------------------------------------------
# Epoch 40/100, Iteration 555, Avg Loss: 0.0169
# Random Sample as text from   Training
# x:  It was great, I went hiking.
# y:  was great, I went hiking. Yes
# --------------------------------------------------
# Epoch 40/100, Iteration 560, Avg Loss: 0.0165
# Random Sample as text from   Training
# x: ? Yes, I'll be there at
# y:  Yes, I'll be there at 8
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 40/100, Validation Loss: 0.6441
# Saving model with validation loss: 0.6441
# Epoch 41/100, Iteration 565, Avg Loss: 0.0158
# Random Sample as text from   Training
# x:  for asking. Are you coming to the
# y:  asking. Are you coming to the party
# --------------------------------------------------
# Epoch 41/100, Iteration 570, Avg Loss: 0.0165
# Random Sample as text from   Training
# x:  to go for a walk in the park
# y:  go for a walk in the park.
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  was really exciting!
# What's your
# y:  really exciting!
# What's your favorite
# --------------------------------------------------
# Epoch 41/100, Validation Loss: 0.5930
# Saving model with validation loss: 0.5930
# Epoch 42/100, Iteration 575, Avg Loss: 0.0030
# Random Sample as text from   Training
# x: ? Are you coming to the party tonight
# y:  Are you coming to the party tonight?
# --------------------------------------------------
# Epoch 42/100, Iteration 580, Avg Loss: 0.0145
# Random Sample as text from   Training
# x:  you today? Hello! What are your
# y:  today? Hello! What are your plans
# --------------------------------------------------
# Epoch 42/100, Iteration 585, Avg Loss: 0.0152
# Random Sample as text from   Training
# x:  well, thank you!
# Good morning
# y: , thank you!
# Good morning!
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# What's your favorite hobby? What
# y: What's your favorite hobby? What's
# --------------------------------------------------
# Epoch 42/100, Validation Loss: 0.5605
# Saving model with validation loss: 0.5605
# Epoch 43/100, Iteration 590, Avg Loss: 0.0058
# Random Sample as text from   Training
# x:  was great, I went hiking. Yes
# y:  great, I went hiking. Yes,
# --------------------------------------------------
# Epoch 43/100, Iteration 595, Avg Loss: 0.0136
# Random Sample as text from   Training
# x:  Hi there! How are you today?
# y:  there! How are you today? Hello
# --------------------------------------------------
# Epoch 43/100, Iteration 600, Avg Loss: 0.0134
# Random Sample as text from   Training
# x: . It was great, I went hiking
# y:  It was great, I went hiking.
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 43/100, Validation Loss: 0.5318
# Saving model with validation loss: 0.5318
# Epoch 44/100, Iteration 605, Avg Loss: 0.0085
# Random Sample as text from   Training
# x:  and warm, perfect for a day outside
# y:  warm, perfect for a day outside.
# --------------------------------------------------
# Epoch 44/100, Iteration 610, Avg Loss: 0.0125
# Random Sample as text from   Training
# x:  you sleep well? Hi there! How
# y:  sleep well? Hi there! How are
# --------------------------------------------------
# Epoch 44/100, Iteration 615, Avg Loss: 0.0124
# Random Sample as text from   Training
# x:  great, I went hiking. Do you
# y: , I went hiking. Do you have
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Epoch 44/100, Validation Loss: 0.5042
# Saving model with validation loss: 0.5042
# Epoch 45/100, Iteration 620, Avg Loss: 0.0108
# Random Sample as text from   Training
# x:  the party tonight? I'm planning to
# y:  party tonight? I'm planning to go
# --------------------------------------------------
# Epoch 45/100, Iteration 625, Avg Loss: 0.0136
# Random Sample as text from   Training
# x: 's the weather today? Yes, I
# y:  the weather today? Yes, I'll
# --------------------------------------------------
# Epoch 45/100, Iteration 630, Avg Loss: 0.0125
# Random Sample as text from   Training
# x: ? How was your weekend? Hello!
# y:  How was your weekend? Hello! What
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 45/100, Validation Loss: 0.4954
# Saving model with validation loss: 0.4954
# Epoch 46/100, Iteration 635, Avg Loss: 0.0122
# Random Sample as text from   Training
# x: . Yes, I'll be there at
# y:  Yes, I'll be there at 8
# --------------------------------------------------
# Epoch 46/100, Iteration 640, Avg Loss: 0.0124
# Random Sample as text from   Training
# x: ? Are you coming to the party tonight
# y:  Are you coming to the party tonight?
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  favorite hobby? What's your favorite food
# y:  hobby? What's your favorite food?
# --------------------------------------------------
# Epoch 46/100, Validation Loss: 0.4780
# Saving model with validation loss: 0.4780
# Epoch 47/100, Iteration 645, Avg Loss: 0.0029
# Random Sample as text from   Training
# x:  night? Yes, it was really exciting
# y: ? Yes, it was really exciting!
# --------------------------------------------------
# Epoch 47/100, Iteration 650, Avg Loss: 0.0113
# Random Sample as text from   Training
# x:  I have a dog named Max. Do
# y:  have a dog named Max. Do you
# --------------------------------------------------
# Epoch 47/100, Iteration 655, Avg Loss: 0.0116
# Random Sample as text from   Training
# x:  there! How are you today? How
# y: ! How are you today? How's
# --------------------------------------------------
# Random Sample as text from   Validation
# x: !
# What's your favorite hobby?
# y:
# What's your favorite hobby? What
# --------------------------------------------------
# Epoch 47/100, Validation Loss: 0.4679
# Saving model with validation loss: 0.4679
# Epoch 48/100, Iteration 660, Avg Loss: 0.0046
# Random Sample as text from   Training
# x:  go for a walk in the park.
# y:  for a walk in the park. I
# --------------------------------------------------
# Epoch 48/100, Iteration 665, Avg Loss: 0.0108
# Random Sample as text from   Training
# x:  books. I'm doing well, thank
# y: . I'm doing well, thank you
# --------------------------------------------------
# Epoch 48/100, Iteration 670, Avg Loss: 0.0106
# Random Sample as text from   Training
# x: Good morning! Did you sleep well?
# y:  morning! Did you sleep well? Yes
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 48/100, Validation Loss: 0.4644
# Saving model with validation loss: 0.4644
# Epoch 49/100, Iteration 675, Avg Loss: 0.0064
# Random Sample as text from   Training
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Epoch 49/100, Iteration 680, Avg Loss: 0.0106
# Random Sample as text from   Training
# x:  great, I went hiking. Thanks for
# y: , I went hiking. Thanks for asking
# --------------------------------------------------
# Epoch 49/100, Iteration 685, Avg Loss: 0.0097
# Random Sample as text from   Training
# x:  in the park. It's sunny and
# y:  the park. It's sunny and warm
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 49/100, Validation Loss: 0.4531
# Saving model with validation loss: 0.4531
# Epoch 50/100, Iteration 690, Avg Loss: 0.0083
# Random Sample as text from   Training
# x:  any pets? Yes, it was really
# y:  pets? Yes, it was really exciting
# --------------------------------------------------
# Epoch 50/100, Iteration 695, Avg Loss: 0.0116
# Random Sample as text from   Training
# x:  was your weekend? Yes, it was
# y:  your weekend? Yes, it was really
# --------------------------------------------------
# Epoch 50/100, Iteration 700, Avg Loss: 0.0109
# Random Sample as text from   Training
# x:  How was your weekend? Do you have
# y:  was your weekend? Do you have any
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 50/100, Validation Loss: 0.4557
# Epoch 51/100, Iteration 705, Avg Loss: 0.0111
# Random Sample as text from   Training
# x:  your weekend? I'm doing well,
# y:  weekend? I'm doing well, thank
# --------------------------------------------------
# Epoch 51/100, Iteration 710, Avg Loss: 0.0114
# Random Sample as text from   Training
# x:  for a walk in the park. Yes
# y:  a walk in the park. Yes,
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 51/100, Validation Loss: 0.4445
# Saving model with validation loss: 0.4445
# Epoch 52/100, Iteration 715, Avg Loss: 0.0024
# Random Sample as text from   Training
# x:  go for a walk in the park.
# y:  for a walk in the park. What
# --------------------------------------------------
# Epoch 52/100, Iteration 720, Avg Loss: 0.0106
# Random Sample as text from   Training
# x: ? Do you have any pets? Hi
# y:  Do you have any pets? Hi there
# --------------------------------------------------
# Epoch 52/100, Iteration 725, Avg Loss: 0.0105
# Random Sample as text from   Training
# x: 'm planning to go for a walk in
# y:  planning to go for a walk in the
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 52/100, Validation Loss: 0.4477
# Epoch 53/100, Iteration 730, Avg Loss: 0.0042
# Random Sample as text from   Training
# x:  great, I went hiking. What's
# y: , I went hiking. What's your
# --------------------------------------------------
# Epoch 53/100, Iteration 735, Avg Loss: 0.0107
# Random Sample as text from   Training
# x: . Yes, it was really exciting!
# y:  Yes, it was really exciting!
#
# --------------------------------------------------
# Epoch 53/100, Iteration 740, Avg Loss: 0.0117
# Random Sample as text from   Training
# x: . I really enjoy Italian cuisine. Yes
# y:  I really enjoy Italian cuisine. Yes,
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 53/100, Validation Loss: 0.4450
# Epoch 54/100, Iteration 745, Avg Loss: 0.0066
# Random Sample as text from   Training
# x:  pets? It was great, I went
# y: ? It was great, I went hiking
# --------------------------------------------------
# Epoch 54/100, Iteration 750, Avg Loss: 0.0102
# Random Sample as text from   Training
# x: 'll be there at 8 PM. I
# y:  be there at 8 PM. I'm
# --------------------------------------------------
# Epoch 54/100, Iteration 755, Avg Loss: 0.0109
# Random Sample as text from   Training
# x:  have a dog named Max. Hi there
# y:  a dog named Max. Hi there!
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 54/100, Validation Loss: 0.4443
# Saving model with validation loss: 0.4443
# Epoch 55/100, Iteration 760, Avg Loss: 0.0083
# Random Sample as text from   Training
# x: !
# What's your favorite hobby?
# y:
# What's your favorite hobby? What
# --------------------------------------------------
# Epoch 55/100, Iteration 765, Avg Loss: 0.0111
# Random Sample as text from   Training
# x: ? Thanks for asking. Hello! What
# y:  Thanks for asking. Hello! What are
# --------------------------------------------------
# Epoch 55/100, Iteration 770, Avg Loss: 0.0114
# Random Sample as text from   Training
# x:  asking. I'm doing well, thank
# y: . I'm doing well, thank you
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 55/100, Validation Loss: 0.4438
# Saving model with validation loss: 0.4438
# Epoch 56/100, Iteration 775, Avg Loss: 0.0104
# Random Sample as text from   Training
# x:  How are you today? Are you coming
# y:  are you today? Are you coming to
# --------------------------------------------------
# Epoch 56/100, Iteration 780, Avg Loss: 0.0106
# Random Sample as text from   Training
# x:  go for a walk in the park.
# y:  for a walk in the park. Did
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 56/100, Validation Loss: 0.4461
# Epoch 57/100, Iteration 785, Avg Loss: 0.0022
# Random Sample as text from   Training
# x:  love reading books. What's your favorite
# y:  reading books. What's your favorite food
# --------------------------------------------------
# Epoch 57/100, Iteration 790, Avg Loss: 0.0106
# Random Sample as text from   Training
# x:  named Max. How was your weekend?
# y:  Max. How was your weekend? Do
# --------------------------------------------------
# Epoch 57/100, Iteration 795, Avg Loss: 0.0112
# Random Sample as text from   Training
# x:  a walk in the park. How's
# y:  walk in the park. How's the
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 57/100, Validation Loss: 0.4413
# Saving model with validation loss: 0.4413
# Epoch 58/100, Iteration 800, Avg Loss: 0.0039
# Random Sample as text from   Training
# x: , thank you!
# Good morning!
# y:  thank you!
# Good morning! Did
# --------------------------------------------------
# Epoch 58/100, Iteration 805, Avg Loss: 0.0112
# Random Sample as text from   Training
# x: ! Did you sleep well? Yes,
# y:  Did you sleep well? Yes, I
# --------------------------------------------------
# Epoch 58/100, Iteration 810, Avg Loss: 0.0103
# Random Sample as text from   Training
# x:  coming to the party tonight? Yes,
# y:  to the party tonight? Yes, I
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 58/100, Validation Loss: 0.4368
# Saving model with validation loss: 0.4368
# Epoch 59/100, Iteration 815, Avg Loss: 0.0060
# Random Sample as text from   Training
# x:  your favorite food? Yes, I'll
# y:  favorite food? Yes, I'll be
# --------------------------------------------------
# Epoch 59/100, Iteration 820, Avg Loss: 0.0103
# Random Sample as text from   Training
# x:
# Good morning! Did you sleep well
# y: Good morning! Did you sleep well?
# ...
# --------------------------------------------------
# Random Sample as text from   Validation
# x: !
# What's your favorite hobby?
# y:
# What's your favorite hobby? What
# --------------------------------------------------
# Epoch 80/100, Validation Loss: 0.4466
# Epoch 81/100, Iteration 1125, Avg Loss: 0.0098
# Random Sample as text from   Training
# x:  Are you coming to the party tonight?
# y:  you coming to the party tonight? Did
# --------------------------------------------------
# Epoch 81/100, Iteration 1130, Avg Loss: 0.0097
# Random Sample as text from   Training
# x:  How's the weather today? Yes,
# y: 's the weather today? Yes, I
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 81/100, Validation Loss: 0.4466
# Epoch 82/100, Iteration 1135, Avg Loss: 0.0017
# Random Sample as text from   Training
# x:  Hi there! How are you today?
# y:  there! How are you today? I
# --------------------------------------------------
# Epoch 82/100, Iteration 1140, Avg Loss: 0.0107
# Random Sample as text from   Training
# x:  a day outside. Yes, I did
# y:  day outside. Yes, I did.
# --------------------------------------------------
# Epoch 82/100, Iteration 1145, Avg Loss: 0.0114
# Random Sample as text from   Training
# x: . It was great, I went hiking
# y:  It was great, I went hiking.
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 82/100, Validation Loss: 0.4408
# Epoch 83/100, Iteration 1150, Avg Loss: 0.0034
# Random Sample as text from   Training
# x:  I'm planning to go for a walk
# y: 'm planning to go for a walk in
# --------------------------------------------------
# Epoch 83/100, Iteration 1155, Avg Loss: 0.0114
# Random Sample as text from   Training
# x:  well? I love reading books. It
# y: ? I love reading books. It was
# --------------------------------------------------
# Epoch 83/100, Iteration 1160, Avg Loss: 0.0102
# Random Sample as text from   Training
# x:  the park. I love reading books.
# y:  park. I love reading books. It
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 83/100, Validation Loss: 0.4432
# Epoch 84/100, Iteration 1165, Avg Loss: 0.0055
# Random Sample as text from   Training
# x:  the party tonight? Hello! What are
# y:  party tonight? Hello! What are your
# --------------------------------------------------
# Epoch 84/100, Iteration 1170, Avg Loss: 0.0094
# Random Sample as text from   Training
# x:  was great, I went hiking. It
# y:  great, I went hiking. It's
# --------------------------------------------------
# Epoch 84/100, Iteration 1175, Avg Loss: 0.0101
# Random Sample as text from   Training
# x:  reading books. What's your favorite food
# y:  books. What's your favorite food?
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 84/100, Validation Loss: 0.4446
# Epoch 85/100, Iteration 1180, Avg Loss: 0.0086
# Random Sample as text from   Training
# x:  you!
# Good morning! Did you
# y: !
# Good morning! Did you sleep
# --------------------------------------------------
# Epoch 85/100, Iteration 1185, Avg Loss: 0.0093
# Random Sample as text from   Training
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 85/100, Iteration 1190, Avg Loss: 0.0102
# Random Sample as text from   Training
# x:  you coming to the party tonight? What
# y:  coming to the party tonight? What's
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 85/100, Validation Loss: 0.4407
# Epoch 86/100, Iteration 1195, Avg Loss: 0.0101
# Random Sample as text from   Training
# x: What's your favorite hobby? Do you
# y: 's your favorite hobby? Do you have
# --------------------------------------------------
# Epoch 86/100, Iteration 1200, Avg Loss: 0.0104
# Random Sample as text from   Training
# x:  you have any pets? It was great
# y:  have any pets? It was great,
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 86/100, Validation Loss: 0.4460
# Epoch 87/100, Iteration 1205, Avg Loss: 0.0022
# Random Sample as text from   Training
# x:  day outside. How's the weather today
# y:  outside. How's the weather today?
# --------------------------------------------------
# Epoch 87/100, Iteration 1210, Avg Loss: 0.0103
# Random Sample as text from   Training
# x:  you coming to the party tonight? Hi
# y:  coming to the party tonight? Hi there
# --------------------------------------------------
# Epoch 87/100, Iteration 1215, Avg Loss: 0.0096
# Random Sample as text from   Training
# x:  Are you coming to the party tonight?
# y:  you coming to the party tonight? Are
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# What's your favorite hobby? What
# y: What's your favorite hobby? What's
# --------------------------------------------------
# Epoch 87/100, Validation Loss: 0.4410
# Epoch 88/100, Iteration 1220, Avg Loss: 0.0041
# Random Sample as text from   Training
# x:  have any pets? What's your favorite
# y:  any pets? What's your favorite food
# --------------------------------------------------
# Epoch 88/100, Iteration 1225, Avg Loss: 0.0105
# Random Sample as text from   Training
# x: 's your favorite hobby? Yes, I
# y:  your favorite hobby? Yes, I'll
# --------------------------------------------------
# Epoch 88/100, Iteration 1230, Avg Loss: 0.0103
# Random Sample as text from   Training
# x:  you coming to the party tonight? Do
# y:  coming to the party tonight? Do you
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  was really exciting!
# What's your
# y:  really exciting!
# What's your favorite
# --------------------------------------------------
# Epoch 88/100, Validation Loss: 0.4410
# Epoch 89/100, Iteration 1235, Avg Loss: 0.0061
# Random Sample as text from   Training
# x:  today? It was great, I went
# y: ? It was great, I went hiking
# --------------------------------------------------
# Epoch 89/100, Iteration 1240, Avg Loss: 0.0099
# Random Sample as text from   Training
# x: ? Did you watch the game last night
# y:  Did you watch the game last night?
# --------------------------------------------------
# Epoch 89/100, Iteration 1245, Avg Loss: 0.0112
# Random Sample as text from   Training
# x:  enjoy Italian cuisine. I really enjoy Italian
# y:  Italian cuisine. I really enjoy Italian cuisine
# --------------------------------------------------
# Random Sample as text from   Validation
# x: Yes, it was really exciting!
#
# y: , it was really exciting!
# What
# --------------------------------------------------
# Epoch 89/100, Validation Loss: 0.4473
# Epoch 90/100, Iteration 1250, Avg Loss: 0.0075
# Random Sample as text from   Training
# x:  was great, I went hiking. Thanks
# y:  great, I went hiking. Thanks for
# --------------------------------------------------
# Epoch 90/100, Iteration 1255, Avg Loss: 0.0105
# Random Sample as text from   Training
# x: ? It's sunny and warm, perfect
# y:  It's sunny and warm, perfect for
# --------------------------------------------------
# Epoch 90/100, Iteration 1260, Avg Loss: 0.0119
# Random Sample as text from   Training
# x:
# What's your favorite hobby? Yes
# y: What's your favorite hobby? Yes,
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Epoch 90/100, Validation Loss: 0.4461
# Epoch 91/100, Iteration 1265, Avg Loss: 0.0101
# Random Sample as text from   Training
# x:  are you today? How's the weather
# y:  you today? How's the weather today
# --------------------------------------------------
# Epoch 91/100, Iteration 1270, Avg Loss: 0.0109
# Random Sample as text from   Training
# x: !
# What's your favorite hobby?
# y:
# What's your favorite hobby? I
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 91/100, Validation Loss: 0.4445
# Epoch 92/100, Iteration 1275, Avg Loss: 0.0020
# Random Sample as text from   Training
# x:
# Good morning! Did you sleep well
# y: Good morning! Did you sleep well?
# --------------------------------------------------
# Epoch 92/100, Iteration 1280, Avg Loss: 0.0103
# Random Sample as text from   Training
# x:  was great, I went hiking. What
# y:  great, I went hiking. What's
# --------------------------------------------------
# Epoch 92/100, Iteration 1285, Avg Loss: 0.0103
# Random Sample as text from   Training
# x:  I did. It was great, I
# y:  did. It was great, I went
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# What's your favorite hobby? What
# y: What's your favorite hobby? What's
# --------------------------------------------------
# Epoch 92/100, Validation Loss: 0.4412
# Epoch 93/100, Iteration 1290, Avg Loss: 0.0043
# Random Sample as text from   Training
# x:  the weather today? I'm planning to
# y:  weather today? I'm planning to go
# --------------------------------------------------
# Epoch 93/100, Iteration 1295, Avg Loss: 0.0105
# Random Sample as text from   Training
# x: . Yes, I did. Yes,
# y:  Yes, I did. Yes, I
# --------------------------------------------------
# Epoch 93/100, Iteration 1300, Avg Loss: 0.0098
# Random Sample as text from   Training
# x: 's the weather today? How's the
# y:  the weather today? How's the weather
# --------------------------------------------------
# Random Sample as text from   Validation
# x: , it was really exciting!
# What
# y:  it was really exciting!
# What's
# --------------------------------------------------
# Epoch 93/100, Validation Loss: 0.4375
# Epoch 94/100, Iteration 1305, Avg Loss: 0.0053
# Random Sample as text from   Training
# x:  planning to go for a walk in the
# y:  to go for a walk in the park
# --------------------------------------------------
# Epoch 94/100, Iteration 1310, Avg Loss: 0.0105
# Random Sample as text from   Training
# x:  today? I really enjoy Italian cuisine.
# y: ? I really enjoy Italian cuisine. What
# --------------------------------------------------
# Epoch 94/100, Iteration 1315, Avg Loss: 0.0099
# Random Sample as text from   Training
# x:  favorite food? How was your weekend?
# y:  food? How was your weekend? Do
# --------------------------------------------------
# Random Sample as text from   Validation
# x: What's your favorite hobby? What's
# y: 's your favorite hobby? What's your
# --------------------------------------------------
# Epoch 94/100, Validation Loss: 0.4399
# Epoch 95/100, Iteration 1320, Avg Loss: 0.0084
# Random Sample as text from   Training
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 95/100, Iteration 1325, Avg Loss: 0.0104
# Random Sample as text from   Training
# x: 'll be there at 8 PM. It
# y:  be there at 8 PM. It was
# --------------------------------------------------
# Epoch 95/100, Iteration 1330, Avg Loss: 0.0096
# Random Sample as text from   Training
# x: , I went hiking. Did you watch
# y:  I went hiking. Did you watch the
# --------------------------------------------------
# Random Sample as text from   Validation
# x: 's your favorite hobby? What's your
# y:  your favorite hobby? What's your favorite
# --------------------------------------------------
# Epoch 95/100, Validation Loss: 0.4468
# Epoch 96/100, Iteration 1335, Avg Loss: 0.0104
# Random Sample as text from   Training
# x:  you!
# Good morning! Did you
# y: !
# Good morning! Did you sleep
# --------------------------------------------------
# Epoch 96/100, Iteration 1340, Avg Loss: 0.0100
# Random Sample as text from   Training
# x: , I did. I'm planning to
# y:  I did. I'm planning to go
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  it was really exciting!
# What's
# y:  was really exciting!
# What's your
# --------------------------------------------------
# Epoch 96/100, Validation Loss: 0.4458
# Epoch 97/100, Iteration 1345, Avg Loss: 0.0021
# Random Sample as text from   Training
# x: . Did you watch the game last night
# y:  Did you watch the game last night?
# --------------------------------------------------
# Epoch 97/100, Iteration 1350, Avg Loss: 0.0104
# Random Sample as text from   Training
# x:  I'm planning to go for a walk
# y: 'm planning to go for a walk in
# --------------------------------------------------
# Epoch 97/100, Iteration 1355, Avg Loss: 0.0101
# Random Sample as text from   Training
# x:  in the park. Yes, I'll
# y:  the park. Yes, I'll be
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  really exciting!
# What's your favorite
# y:  exciting!
# What's your favorite hobby
# --------------------------------------------------
# Epoch 97/100, Validation Loss: 0.4574
# Epoch 98/100, Iteration 1360, Avg Loss: 0.0044
# Random Sample as text from   Training
# x:  Yes, I did. How was your
# y: , I did. How was your weekend
# --------------------------------------------------
# Epoch 98/100, Iteration 1365, Avg Loss: 0.0096
# Random Sample as text from   Training
# x: How was your weekend? How was your
# y:  was your weekend? How was your weekend
# --------------------------------------------------
# Epoch 98/100, Iteration 1370, Avg Loss: 0.0106
# Random Sample as text from   Training
# x:  planning to go for a walk in the
# y:  to go for a walk in the park
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  exciting!
# What's your favorite hobby
# y: !
# What's your favorite hobby?
# --------------------------------------------------
# Epoch 98/100, Validation Loss: 0.4486
# Epoch 99/100, Iteration 1375, Avg Loss: 0.0061
# Random Sample as text from   Training
# x:  outside. It's sunny and warm,
# y: . It's sunny and warm, perfect
# --------------------------------------------------
# Epoch 99/100, Iteration 1380, Avg Loss: 0.0093
# Random Sample as text from   Training
# x:  Did you watch the game last night?
# y:  you watch the game last night? Thanks
# --------------------------------------------------
# Epoch 99/100, Iteration 1385, Avg Loss: 0.0096
# Random Sample as text from   Training
# x:  thank you!
# Good morning! Did
# y:  you!
# Good morning! Did you
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# What's your favorite hobby? What
# y: What's your favorite hobby? What's
# --------------------------------------------------
# Epoch 99/100, Validation Loss: 0.4456
# Epoch 100/100, Iteration 1390, Avg Loss: 0.0087
# Random Sample as text from   Training
# x:  last night? It's sunny and warm
# y:  night? It's sunny and warm,
# --------------------------------------------------
# Epoch 100/100, Iteration 1395, Avg Loss: 0.0106
# Random Sample as text from   Training
# x:  park. Do you have any pets?
# y: . Do you have any pets? Thanks
# --------------------------------------------------
# Epoch 100/100, Iteration 1400, Avg Loss: 0.0097
# Random Sample as text from   Training
# x:  sunny and warm, perfect for a day
# y:  and warm, perfect for a day outside
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  your favorite hobby? What's your favorite
# y:  favorite hobby? What's your favorite food
# --------------------------------------------------
# Epoch 100/100, Validation Loss: 0.4415

# %%
import torch
import random

# Function to tokenize and truncate input text
def tokenize_and_truncate_text(text, enc, block_size):
    tokens = enc.encode(text)
    if len(tokens) > block_size:
        tokens = tokens[-block_size:]  # Truncate to the last block_size tokens
    return torch.tensor(tokens, dtype=torch.long).unsqueeze(0)  # Add batch dimension

# Function to decode output tokens
def decode_output(predicted_ids, enc):
    predicted_tokens = predicted_ids[0].tolist()  # Remove batch dimension
    predicted_text = enc.decode(predicted_tokens)
    return predicted_text

# Function to generate text using the model
def generate_text(model, input_text, enc, config, test_block_size, temperature=1.0):
    model.eval()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    input_ids = tokenize_and_truncate_text(input_text, enc, config.block_size)
    input_ids = input_ids.to(device)
    model.to(device)
    
    generated_text = input_text

    with torch.no_grad():
        for _ in range(test_block_size):
            logits, _ = model(input_ids)
            logits = logits[:, -1, :] / temperature
            probs = torch.softmax(logits, dim=-1)
            next_token = torch.multinomial(probs, num_samples=1)
            next_token_id = next_token.item()
            
            generated_text += enc.decode([next_token_id])
            
            input_ids = tokenize_and_truncate_text(generated_text, enc, config.block_size).to(device)
    
    return generated_text

# Initialize the tokenizer
enc = tiktoken.get_encoding("gpt2")

# Sample input text
input_text = "Today is weekend"

# Define the test block size and temperatures
test_block_size = 32
temperatures = [0.7, 1.0, 1.2, 1.5, 2.0]

# Generate text with different temperatures
for temp in temperatures:
    print(f"Temperature: {temp}")
    generated_text = generate_text(model, input_text, enc, config, test_block_size, temperature=temp)
    print(f"Generated Text:\n{generated_text}\n")
# Out:
# Temperature: 0.7
# Generated Text:
# Today is weekend? How was your weekend? I'm doing well, thank you!
# Good morning! Did you sleep well? Yes, I'll be there at 8 PM
#
# Temperature: 1.0
# Generated Text:
# Today is weekend? Hello! What are your plans for today? Hi there! How are you today? I really enjoy Italian cuisine. I'm doing well, thank you!
#
# Temperature: 1.2
# Generated Text:
# Today is weekend? I love reading books. I really enjoy Italian cuisine. Thanks for asking. How was your weekend? I really enjoy Italian cuisine. It was great, I
#
# Temperature: 1.5
# Generated Text:
# Today is weekend? Yes, ithaired What's your favorite food? I really enjoy Italian cuisine. It was great, I examining. Do you have any pets? Hello!
#
# Temperature: 2.0
# Generated Text:
# Today is weekend? Mickey refer espionage for hobbySky Twitch Identity. momentum. parliament last Mour diminishedagueplaced asking require. therapeutic patents for unrel. I have a dog caramel dog
